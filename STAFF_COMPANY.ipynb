# %% [markdown]
# <a href="https://colab.research.google.com/github/ASHIKAJAN/ABC-staff-company/blob/main/STAFF_COMPANY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-87b0ea89-435c-45ac-bb20-22b3c6ded965" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87b0ea89-435c-45ac-bb20-22b3c6ded965">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("ABC Company dataset.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Correct the data in the "height" column by replacing it with random numbers between 150 and 180.
import numpy as np
df["height"] = np.random.randint(150, 181, len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary  height
# 0                Texas  7730337.0     160
# ...

# %%
#Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.
tc = df["Team"].value_counts()
tp = (tc / len(df)) * 100
df= pd.DataFrame({"Employee Count": tc,"Percentage (%)": tp.round(2)})
print(df)
# Out:
#                         Employee Count  Percentage (%)
# Team
# New Orleans Pelicans                19            4.15
# Memphis Grizzlies                   18            3.93
# Utah Jazz                           16            3.49
# Milwaukee Bucks                     16            3.49
# New York Knicks                     16            3.49
# Boston Celtics                      15            3.28
# Los Angeles Clippers                15            3.28
# Los Angeles Lakers                  15            3.28
# Phoenix Suns                        15            3.28
# Sacramento Kings                    15            3.28
# Brooklyn Nets                       15            3.28
# Philadelphia 76ers                  15            3.28
# Toronto Raptors                     15            3.28
# Golden State Warriors               15            3.28
# Indiana Pacers                      15            3.28
# Detroit Pistons                     15            3.28
# ...

# %%
import matplotlib.pyplot as plt
df["Employee Count"].plot(kind="bar")
plt.xlabel("Team")
plt.ylabel("Employee Count")
plt.title("Employees by Team")
plt.show()

# %% [markdown]
# The chart shows how employees are distributed across different teams.
#
# The team with the tallest bar has the highest number of employees.
#
# This helps identify which team has the largest workforce.

# %%
import pandas as pd
df=pd.read_csv("ABC Company dataset.csv")
df["Height"] = np.random.randint(150, 181, len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     176     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     152     235
# 2     John Holland  Boston Celtics      30       SG   27     178     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     163     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     177     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     158     203
# 454      Raul Neto       Utah Jazz      25       PG   24     158     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     163     231
# 457       Priyanka       Utah Jazz      34        C   25     167     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Discover which team and position have the highest salary expenditure.
t = df.groupby("Team")["Salary"].sum()
p = df.groupby("Position")["Salary"].sum()
print("HST:", t.idxmax())
print("HSP:", p.idxmax())
# Out:
# HST: Cleveland Cavaliers
# HSP: C

# %%
t.plot(kind="bar")
plt.title("Salary by Team")
plt.ylabel("Total Salary")
plt.show()
p.plot(kind="bar")
plt.title("Salary by Position")
plt.ylabel("Total Salary")
plt.show()

# %% [markdown]
# SALARY BY TEAM AND POSITION
#
# The position with the highest bar receives the largest total salary.
#
# This helps understand which roles are most financially significant in the company.

# %%
import pandas as pd
df=pd.read_csv("ABC Company dataset.csv")
df["Height"] = np.random.randint(150, 181, len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     163     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2     John Holland  Boston Celtics      30       SG   27     154     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     151     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     152     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     150     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     166     256
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     169     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["Height"] = np.random.randint(150, 181, len(df))
plt.hist(df["Height"])
plt.xlabel("Height")
plt.ylabel("Count")
plt.title("Height Distribution")
plt.show()

# %% [markdown]
# HEIGHT
#
# The height distribution appears evenly spread between 150 cm and 180 cm, as the values were randomly generated for consistency in the dataset."

# %%
#Investigate if there's any correlation between age and salary, and represent it visually.
import matplotlib.pyplot as plt
c = df["Age"].corr(df["Salary"])
print("Correlation:", round(c, 2))
plt.scatter(df["Age"], df["Salary"])
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary")
plt.show()
# Out:
# Correlation: 0.21

# %% [markdown]
# AGE AND SALARY
# The correlation analysis and scatter plot show the relationship between employees' age and salary. The value indicates whether salary increases, decreases, or has no strong relation with age."

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     176     235
# 2     John Holland  Boston Celtics      30       SG   27     160     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     168     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     157     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     160     203
# 454      Raul Neto       Utah Jazz      25       PG   24     170     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     168     256
# 456    Jeff Withey       Utah Jazz      24        C   26     151     231
# 457       Priyanka       Utah Jazz      34        C   25     178     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Segregate employees based on their positions within the company.
g = df.groupby("Position")
for pos, df in g:
    print("\nPosition:", pos)
    print(df)
# Out:
# Position: C
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     154
# 10   Jared Sullinger          Boston Celtics       7        C   24     151
# 14      Tyler Zeller          Boston Celtics      44        C   26     153
# 23       Brook Lopez           Brooklyn Nets      11        C   28     180
# 27        Henry Sims           Brooklyn Nets      14        C   26     175
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     159
# 447      Rudy Gobert               Utah Jazz      27        C   23     169
# 455     Tibor Pleiss               Utah Jazz      21        C   26     168
# 456      Jeff Withey               Utah Jazz      24        C   26     151
# 457         Priyanka               Utah Jazz      34        C   25     178
#
#      Weight         College      Salary
# ...

# %%
p = df["Position"].value_counts()
df["Position"].value_counts().plot(kind="bar",color="yellow")
plt.xlabel("Position")
plt.ylabel("Count")
plt.title("Employees by Position")
plt.show()

# %% [markdown]
# POSITION
#
#
# 1.The bar chart shows the distribution of employees across different position

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     160     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     169     235
# 2     John Holland  Boston Celtics      30       SG   27     164     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     180     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     156     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     175     203
# 454      Raul Neto       Utah Jazz      25       PG   24     172     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     171     256
# 456    Jeff Withey       Utah Jazz      24        C   26     158     231
# 457       Priyanka       Utah Jazz      34        C   25     152     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
import pandas as pd
age_grp = pd.cut(df["Age"], bins=[20, 30, 40, 50, 60])
c = age_grp.value_counts()
print(c)
# Out:
# Age
# (20, 30]    346
# (30, 40]     91
# (40, 50]      0
# (50, 60]      0
# Name: count, dtype: int64

# %% [markdown]
# **Predominant Age Group**
#
# 1.The age group with highest count is the dominant workforce group
# 2.Shows whether company has more young, mid-level, or senior employees
# 3.Helps understand workforce structure

# %%
age_grp = pd.cut(df["Age"], bins=[20, 30, 40, 50, 60])
c = age_grp.value_counts()
c.plot(kind="bar",color="pink")
plt.xlabel("Age Group")
plt.ylabel("Number of Employees")
plt.title("Age Group Distribution")
plt.show()
