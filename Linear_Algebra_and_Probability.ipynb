# %% [markdown]
# <a href="https://colab.research.google.com/github/ASHIKAJAN/ABC-staff-company/blob/main/Linear_Algebra_and_Probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d635c232-8e27-43bf-a484-033dc6a7f6a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d635c232-8e27-43bf-a484-033dc6a7f6a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv',sep=';')

df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df = df.fillna(df.mean())

# %%
alcohol = df['alcohol']
citric_acid = df['citric acid']

print("Alcohol (first 5):")
print(alcohol.head())

print("\nCitric Acid (first 5):")
print(citric_acid.head())
# Out:
# Alcohol (first 5):
# 0    9.4
# 1    9.8
# 2    9.8
# 3    9.8
# 4    9.4
# Name: alcohol, dtype: float64
#
# Citric Acid (first 5):
# 0    0.00
# 1    0.00
# 2    0.04
# 3    0.56
# 4    0.00
# Name: citric acid, dtype: float64

# %%
X = df[['alcohol', 'density']]
cov_matrix = np.cov(X.T)

print("\nCovariance Matrix:")
print(cov_matrix)
# Out:
# Covariance Matrix:
# [[ 1.13564740e+00 -9.97951790e-04]
#  [-9.97951790e-04  3.56202945e-06]]

# %%
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

print("\nEigenvalues:")
print(eigenvalues)

print("\nEigenvectors:")
print(eigenvectors)
# Out:
# Eigenvalues:
# [1.13564827e+00 2.68507580e-06]
#
# Eigenvectors:
# [[ 9.99999614e-01  8.78753184e-04]
#  [-8.78753184e-04  9.99999614e-01]]

# %%
most_common = df['quality'].mode()[0]

print("\nMost common wine quality:", most_common)
# Out:
# Most common wine quality: 5
